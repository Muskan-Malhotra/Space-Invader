# %%
import pygame

pygame.init()
pygame.font.init()

White = (255,255,255)
LIGHT = (255,255,0)
BLACK = ( 0, 0, 0)

font = pygame.font.SysFont('Comic Sans MS', 38)
myfont = pygame.font.SysFont('Comic Sans MS', 50)
Font = pygame.font.SysFont("Comic Sans MS", 55)
myfont_text = pygame.font.SysFont('Comic Sans MS', 35)

windw = pygame.display.set_mode((1500,1000))
pygame.display.set_caption('SPACE EXPLOSION')
clock=pygame.time.Clock()
pygame.mixer.music.load('sound.mp3')
pygame.mixer.music.play(-1,0.0)

done = False
level = 0
sprite1 = 5
sprite2 = 10
sprite3 = 15

backgrnd = pygame.image.load("space.jpg").convert()

page = 'mainscreen'

def exitpage():
    global done, page

    windw.blit(backgrnd, (0,0))
    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
    
    rect = pygame.image.load("rect0.jpg")
    rect = pygame.transform.scale(rect, (780,380))
    windw.blit(rect, (350,125))

    #pygame.draw.rect(windw, WHITE, (450, 300, 600, 300))

    textsurface = myfont.render('Do you really want to exit?', False, White)
    windw.blit(textsurface, (425,185))
    
    bot2=pygame.image.load("bot2.jpg")
    bot2 = pygame.transform.scale(bot2, (159, 65))
    windw.blit(bot2, (500, 348))
    
    if mouse[0] < 659 and mouse[0] > 500 and mouse[1] < 413 and mouse[1] > 348:
        if click[0] == 1:
            image1 = pygame.transform.scale(bot2, (130, 58))
            windw.blit(image1,(500,348))
            page = 'mainscreen'
        else:
            image1 = pygame.transform.scale(bot2, (160, 70))
            windw.blit(image1,(500,348))
    textsurface = myfont.render('Cancel', False, White)
    windw.blit(textsurface, (506,345))

    
    bot2=pygame.image.load("bot2.jpg")
    bot2 = pygame.transform.scale(bot2, (159, 65))
    windw.blit(bot2, (780, 348))
    
    if mouse[0] < 929 and mouse[0] > 780 and mouse[1] < 413 and mouse[1] > 348:
        if click[0] == 1:
            image1 = pygame.transform.scale(bot2, (159, 64))
            windw.blit(image1,(780,348))
            done = True
        else:
            image1 = pygame.transform.scale(bot2, (160, 70))
            windw.blit(image1,(780,348))
    textsurface = myfont.render('Exit', False, White)
    windw.blit(textsurface, (815,345))


def howtoplay():
    global page, sprite1, sprite2, sprite3

    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
    windw.blit(backgrnd, (0,0))

    textsurface = Font.render('Controls', False, White)
    windw.blit(textsurface, (660, 50))

    ctrls = pygame.image.load("keyboard.png").convert()
    windw.blit(ctrls, (450,150))

    pygame.draw.arc(windw, BLACK, (890,310,70,120), 180*3.14/180, 270*3.14/180, 3)
    pygame.draw.arc(windw, BLACK, (950,325,180,90), 180*3.14/180, 270*3.14/180, 3)
    pygame.draw.arc(windw, BLACK, (580,308,90,120), 270*3.14/180, 360*3.14/180, 3)
    textsurface = Font.render('Scoring', False, White)
    windw.blit(textsurface, (660, 465))

    for i in range(1,4):
        img = pygame.image.load('sprite'+str(i)+'.jpeg')
        img = pygame.transform.scale(img, (70,70))
        windw.blit(img, (600, 480+i*80))

    textsurface = font.render(str(sprite1)+'   points', False, LIGHT)
    windw.blit(textsurface, (720, 475+1*90))

    textsurface = font.render(str(sprite2)+'   points', False, LIGHT)
    windw.blit(textsurface, (720, 465+2*90))

    textsurface = font.render(str(sprite3)+'   points', False, LIGHT)
    windw.blit(textsurface, (720, 465+3*90))
    
    bot4=pygame.image.load("bot2.jpg")
    bot4 = pygame.transform.scale(bot4, (100, 55))
    windw.blit(bot4, (1300, 732))

    if mouse[0] < 1400 and mouse[0] > 1300 and mouse[1] < 787 and mouse[1] > 732:
        if click[0]:
            image1 = pygame.transform.scale(bot4, (100, 54))
            windw.blit(image1,(1300, 732))
            page = 'mainscreen'
        else:
            image1 = pygame.transform.scale(bot4, (120, 60))
            windw.blit(image1,(1300, 732))

    textsurface = myfont_text.render('Back', False, White)
    windw.blit(textsurface, (1310, 735))
    
    textsurface = myfont_text.render('SHOOT', False, LIGHT)
    windw.blit(textsurface, (490,400))

    textsurface = myfont_text.render('MOVE LEFT', False, LIGHT)
    windw.blit(textsurface, (830,425))

    textsurface = myfont_text.render('MOVE RIGHT', False, LIGHT)
    windw.blit(textsurface, (1040,385))

def newgame():
    global page, level

    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
    windw.blit(backgrnd, (0,0))
    
    rec = pygame.image.load("rect0.jpg")
    rec = pygame.transform.scale(rec, (650,755))
    windw.blit(rec, (650,70))
    
    bot3=pygame.image.load("bot2.jpg")
    bot3 = pygame.transform.scale(bot3, (350, 75))
    windw.blit(bot3, (740, 300))

    textsurface = Font.render('Difficulty Levels', False, White)
    windw.blit(textsurface, (775,150))

    if mouse[0] < 1100 and mouse[0] > 750 and mouse[1] < 375 and mouse[1] > 300:
        if click[0]:
            image1 = pygame.transform.scale(bot3, (355, 76))
            windw.blit(image1,(740,300))
            level = 1
        else:
            image1 = pygame.transform.scale(bot3, (365, 80))
            windw.blit(image1,(740,300))

    textsurface = myfont.render('Let me try', False, White)
    windw.blit(textsurface, (790, 300))
    
    bot3 = pygame.transform.scale(bot3, (350, 75))
    windw.blit(bot3, (800, 425))

    if mouse[0] < 1160 and mouse[0] > 810 and mouse[1] < 490 and mouse[1] > 425:
        if click[0]:
            image1 = pygame.transform.scale(bot3, (355, 76))
            windw.blit(image1,(800,425))
            level = 2
        else:
            image1 = pygame.transform.scale(bot3, (365, 80))
            windw.blit(image1,(800,425))

    textsurface = myfont.render('Bring them on', False, White)
    windw.blit(textsurface, (815, 427))
    
    bot3 = pygame.transform.scale(bot3, (350, 75))
    windw.blit(bot3, (870, 550))

    if mouse[0] < 1220 and mouse[0] > 870 and mouse[1] < 625 and mouse[1] > 550:
        if click[0]:
            image1 = pygame.transform.scale(bot3, (355, 76))
            windw.blit(image1,(870,550))
            level = 3
        else:
            image1 = pygame.transform.scale(bot3, (365, 80))
            windw.blit(image1,(870,550))
            
    textsurface = myfont.render('Begin the war', False, White)
    windw.blit(textsurface, (885, 553))
    
    bot3 = pygame.transform.scale(bot3, (150, 65))
    windw.blit(bot3, (950, 670))

    if mouse[0] < 1100 and mouse[0] > 950 and mouse[1] < 735 and mouse[1] > 670:
        if click[0]:
            image1 = pygame.transform.scale(bot3, (155, 66))
            windw.blit(image1,(950,670))
            page = 'mainscreen'
        else:
            image1 = pygame.transform.scale(bot3, (160, 70))
            windw.blit(image1,(950,670))

    textsurface = myfont.render('Back', False, White)
    windw.blit(textsurface, (970, 668))

def mainscreen():
    global done, page

    windw.blit(backgrnd, [0,0])
    title = pygame.image.load("grnd.jpg")
    title = pygame.transform.scale(title, (800,150))

    windw.blit(title, (360, 30))

    bot1=pygame.image.load("bot1.jpg")
    bot1 = pygame.transform.scale(bot1, (230, 65))

    windw.blit(bot1, (1060, 410))
    windw.blit(bot1, (1060, 485))
    windw.blit(bot1, (1060, 560))
    windw.blit(bot1, (1060, 635))
    windw.blit(bot1, (1060, 711))
    
    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
    if mouse[0] < 1290 and mouse[0]> 1060 and mouse[1] < 475 and mouse[1] > 410:
        if click[0] == 1:
            image = pygame.transform.scale(bot1, (230, 63))
            windw.blit(image,(1060,410))
            page = 'newgame'
        else:
            image = pygame.transform.scale(bot1, (240, 70))
            windw.blit(image,(1060,410))
            
        
    text = font.render('New Game', False, White)
    windw.blit(text,(1086,415))
    
    if mouse[0] < 1290 and mouse[0] > 1060 and mouse[1] < 550 and mouse[1] > 485:
        if click[0] == 1:
            image1 = pygame.transform.scale(bot1, (230, 63))
            windw.blit(image1,(1060,485))
        else:
            image1 = pygame.transform.scale(bot1, (240, 70))
            windw.blit(image1,(1060,485))
            
    text = font.render('Resume', False, White)
    windw.blit(text,(1108,490))
    
    if mouse[0] < 1290 and mouse[0] > 1060 and mouse[1] < 625 and mouse[1] > 560:
        if click[0] == 1:
            image2 = pygame.transform.scale(bot1, (230, 63))
            windw.blit(image2,(1060,560))
        else:
            image2 = pygame.transform.scale(bot1, (240, 70))
            windw.blit(image2,(1060,560))
            
    text = font.render('High Score', False, White)
    windw.blit(text,(1078,565))
    
    if mouse[0] < 1290 and mouse[0] > 1060 and mouse[1] < 700 and mouse[1] > 635:
        if click[0] == 1:
            image2 = pygame.transform.scale(bot1, (230, 63))
            windw.blit(image2,(1060,635))
            page = 'howtoplay'
        else:
            image2 = pygame.transform.scale(bot1, (240, 70))
            windw.blit(image2,(1060,635))
            
    text = font.render('How to Play', False, White)
    windw.blit(text,(1075,638))
    
    if mouse[0] < 1290 and mouse[0] > 1060 and mouse[1] < 776 and mouse[1] > 711:
        if click[0] == 1:
            image2 = pygame.transform.scale(bot1, (230, 63))
            windw.blit(image2,(1060,711))
            page = 'exitpage'
        else:
            image2 = pygame.transform.scale(bot1, (240, 70))
            windw.blit(image2,(1060,711))
            
    text = font.render('Exit', False, White)
    windw.blit(text,(1138,718))


#-----------------------------------------------------------------------------------

while done == False:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            done = True


    if page == 'mainscreen':
        mainscreen()
    elif page == 'newgame':
        newgame()
    elif page == 'howtoplay':
        howtoplay()
    elif page == 'exitpage':
        exitpage()

    
    pygame.display.update()




    clock.tick(20) 

pygame.quit()
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import pygame
import random
from time import sleep


pygame.init()
pygame.font.init()

White = (255,255,255)
LIGHT = (255,255,0)
BLACK = ( 0, 0, 0)

font = pygame.font.SysFont('Comic Sans MS', 38)
myfont = pygame.font.SysFont('Comic Sans MS', 50)
Font = pygame.font.SysFont("Comic Sans MS", 55)
myfont_text = pygame.font.SysFont('Comic Sans MS', 35)

windw = pygame.display.set_mode((1500,1000))
pygame.display.set_caption('SPACE EXPLOSION')
clock=pygame.time.Clock()


done = False
level = 0
sprite1 = 5
sprite2 = 10
sprite3 = 15

backgrnd = pygame.image.load("space.jpg").convert()

page = 'mainscreen'

highscore = '0'

#----------------------------------------

spaceS = pygame.image.load("ss1.png")
spaceS = pygame.transform.scale(spaceS,(80,80))
enemy_5 = pygame.image.load('1.png')
enemy_5 = pygame.transform.scale(enemy_5,(80,80))
enemy_5 = pygame.transform.flip(enemy_5,False,True)
enemy_10 = pygame.image.load('2.png')
enemy_10 = pygame.transform.scale(enemy_10,(80,80))
enemy_10 = pygame.transform.flip(enemy_10,False,True)
enemy_15 = pygame.image.load('3.png')
enemy_15 = pygame.transform.scale(enemy_15,(80,80))
enemy_15 = pygame.transform.flip(enemy_15,False,True)
background = pygame.image.load('bg1.jpeg').convert()
destroyed = pygame.image.load("ss2.png")
destroyed = pygame.transform.scale(destroyed,(80,80)) 
enemy = {}
enemy['5'] = enemy_5
enemy['10'] = enemy_10
enemy['15'] = enemy_15
background = pygame.transform.scale(background, (1500, 1000))

sprites = []
lives = 5
level = 1
score = 0

def sound(flag):
    if flag == 0:
        pygame.mixer.music.load('sound.mp3')
        pygame.mixer.music.play(-1,0.0)
    elif flag == 1:
        pygame.mixer.music.load('levelsound.mp3')
        pygame.mixer.music.play(-1,0.0)
    elif flag == 2:
        pygame.mixer.music.load('explosionenemy.mp3')
        pygame.mixer.music.play(-1,0.0)
    elif flag == 3:
        pygame.mixer.music.load('explosionship.mp3')
        pygame.mixer.music.play(-1,0.0)

class spaceShip(object):
    def __init__(self, image, windw, x, y, width, height):
        self.image = image
        self.x = x
        self.y = y
        self.width = width
        self.height = height
        self.vel_ss = 25
        self.left = False
        self.right = False
        self.rect = pygame.Rect(x, y, width, height)

    def draw(self, windw):
        windw.blit(self.image, (self.x, self.y))

class enemys(object):
    def __init__(self, image, windw, x, y, width, height):
        self.image = image
        self.x = x
        self.y = y
        self.width = width
        self.height = height
        self.vel_sx = 10
        self.vel_sy = 3
        self.left = False
        self.right = False
        self.rect = pygame.Rect(x, y, width, height)
        self.point = None

    def draw(self, windw):
        windw.blit(self.image, (self.x, self.y))

class shots(object):
    def __init__(self, x, y, color):
        self.x = x
        self.y = y
        self.height = 10
        self.width = 5
        self.color = color
        self.vel_b = 20
        self.rect = pygame.Rect(x, y, self.width, self.height)

    def draw(self, windw):
        pygame.draw.rect(windw, self.color, (self.x, self.y, self.width, self.height))

def savescore(score):

    file = open('highscore.txt', 'w')
    file.write(str(score))
    file.close()

def redrawWindow(windw, background, SpaceShip, Enemy, bullets, bullete):
    global lives, score, page

    windw.blit(background, (0,0))

    textsurface = myfont.render('Lives  : ' + str(lives), False, White)
    windw.blit(textsurface, (1300, 50))

    textsurface = myfont.render('Score  : ' + str(score), False, White)
    windw.blit(textsurface, (1000, 50))

    SpaceShip.draw(windw)

    for bullet in bullets:
        for E in Enemy:
            if pygame.sprite.collide_rect(bullet,E):
                windw.blit(destroyed, (E.x, E.y))
                score += Enemy[Enemy.index(E)].point
                if score > int(highscore):
                    savescore(score)
                Enemy.pop(Enemy.index(E))
                sound(2)
                bullets.pop(bullets.index(bullet))

    for bullet in bullete:
        if pygame.sprite.collide_rect(bullet, SpaceShip):
            windw.blit(destroyed, (SpaceShip.x, SpaceShip.y))
            bullete.pop(bullete.index(bullet))
            lives -= 1
            sound(3)
            if lives == 0:
                page = 'gameover'
                sound(1)
                return GameOver()
            SpaceShip.x = 710
            SpaceShip.y = 800

    for E in Enemy:
        if pygame.sprite.collide_rect(E, SpaceShip):
            windw.blit(destroyed, (SpaceShip.x, SpaceShip.y))
            windw.blit(destroyed, (E.x, E.y))
            Enemy.pop(Enemy.index(E))
            sound(3)
            lives -= 1
            if lives == 0:
                page = 'gameover'
                sound(1)
                return GameOver()
            SpaceShip.x = 710
            SpaceShip.y = 800

    dirx = random.randint(-1,1)
    diry = random.randint(0,1)
    for E in Enemy:
        E.x -= dirx * E.vel_sx
        E.y += diry * E.vel_sy
        if E.y > 1000:
            Enemy.pop(Enemy.index(E))
            lives -= 1
            if lives == 0:
                page = 'gameover'
                sound(1)
                return GameOver()
        E.rect = pygame.Rect(E.x, E.y, E.width, E.height)



    #------------------------------------------
    #pop out of windw

    for i in range(len(Enemy)):
        Enemy[i].draw(windw)

    for bullet in bullets:
        bullet.draw(windw)

    for bullet in bullete:
        bullet.draw(windw)

    if len(Enemy) == 0:
        sound(1)
        page = 'gameover'

    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
    bot4=pygame.image.load("bot2.jpg")
    bot4 = pygame.transform.scale(bot4, (100, 55))
    windw.blit(bot4, (1300, 732))

    if mouse[0] < 1400 and mouse[0] > 1300 and mouse[1] < 787 and mouse[1] > 732:
        if click[0]:
            image1 = pygame.transform.scale(bot4, (100, 54))
            windw.blit(image1,(1300, 732))
            page = 'newgame'
        else:
            image1 = pygame.transform.scale(bot4, (120, 60))
            windw.blit(image1,(1300, 732))

    textsurface = myfont_text.render('Back', False, White)
    windw.blit(textsurface, (1310, 735))

    pygame.display.update()

def bulletmove(bullets, bullete):
    for bullet in bullets:
        if bullet.y > 0:
            bullet.y -= bullet.vel_b
            bullet.rect = pygame.Rect(bullet.x, bullet.y, bullet.width, bullet.height)
        else:
            bullets.pop(bullets.index(bullet))

    for bullet in bullete:
        if bullet.y < 1000:
            bullet.y += bullet.vel_b
            bullet.rect = pygame.Rect(bullet.x, bullet.y, bullet.width, bullet.height)
        else:
            bullete.pop(bullete.index(bullet))

def enemyshot(E, bullete, level):

    flag = random.randint(0,1000000)

    if flag % 100 == 0:
        bullete.append(shots(round(E.x + 40),round(E.y + 40),(255,0,0)))

    return bullete

def startgame(level, windw):

    global bullets, bullete, page, quit

    if level != 1:
        for E in Enemy:
            bullete = enemyshot(E, bullete ,level)

    bulletmove(bullets, bullete)

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            quit = True

    keys = pygame.key.get_pressed()            

    if keys[pygame.K_SPACE]:

        if len(bullets) < level * 10:
            bullets.append(shots(round(ss.x + 40),round(ss.y +40),(0,255,0)))

    if keys[pygame.K_LEFT]:
        if ss.x > 0:
            ss.x -= ss.vel_ss
            left = True
            right = False
            ss.rect = pygame.Rect(ss.x, ss.y, ss.width, ss.height)
    elif keys[pygame.K_RIGHT]:
        if ss.x < 1500 - ss.width:
            ss.x += ss.vel_ss
            right = True
            left = False
            ss.rect = pygame.Rect(ss.x, ss.y, ss.width, ss.height)
    redrawWindow(windw, background, ss, Enemy, bullets, bullete)

def high():
    global highscore, page
    try:
        file = open('highscore.txt', 'r')
        highscore = file.read()
        file.close()
    except:
        pass

    windw.blit(backgrnd, (0,0))
    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
    bot4=pygame.image.load("bot2.jpg")
    bot4 = pygame.transform.scale(bot4, (100, 55))
    windw.blit(bot4, (1300, 732))

    textsurface = myfont.render('HighScore is : '+ highscore, False, White)
    windw.blit(textsurface, (650, 400))

    if mouse[0] < 1400 and mouse[0] > 1300 and mouse[1] < 787 and mouse[1] > 732:
        if click[0]:
            image1 = pygame.transform.scale(bot4, (100, 54))
            windw.blit(image1,(1300, 732))
            page = 'mainscreen'
        else:
            image1 = pygame.transform.scale(bot4, (120, 60))
            windw.blit(image1,(1300, 732))

    textsurface = myfont_text.render('Back', False, White)
    windw.blit(textsurface, (1310, 735))

def exitpage():
    global done, page

    windw.blit(backgrnd, (0,0))
    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()

    rect = pygame.image.load("rect0.jpg")
    rect = pygame.transform.scale(rect, (780,380))
    windw.blit(rect, (350,125))

    #pygame.draw.rect(windw, WHITE, (450, 300, 600, 300))

    textsurface = myfont.render('Do you really want to exit?', False, White)
    windw.blit(textsurface, (425,185))

    bot2=pygame.image.load("bot2.jpg")
    bot2 = pygame.transform.scale(bot2, (159, 65))
    windw.blit(bot2, (500, 348))

    if mouse[0] < 659 and mouse[0] > 500 and mouse[1] < 413 and mouse[1] > 348:
        if click[0] == 1:
            image1 = pygame.transform.scale(bot2, (130, 58))
            windw.blit(image1,(500,348))
            page = 'mainscreen'
        else:
            image1 = pygame.transform.scale(bot2, (160, 70))
            windw.blit(image1,(500,348))
    textsurface = myfont.render('Cancel', False, White)
    windw.blit(textsurface, (506,351))


    bot2=pygame.image.load("bot2.jpg")
    bot2 = pygame.transform.scale(bot2, (159, 65))
    windw.blit(bot2, (780, 348))

    if mouse[0] < 929 and mouse[0] > 780 and mouse[1] < 413 and mouse[1] > 348:
        if click[0] == 1:
            image1 = pygame.transform.scale(bot2, (159, 64))
            windw.blit(image1,(780,348))
            done = True
        else:
            image1 = pygame.transform.scale(bot2, (160, 70))
            windw.blit(image1,(780,348))
    textsurface = myfont.render('Exit', False, White)
    windw.blit(textsurface, (815,351))

def howtoplay():
    global page, sprite1, sprite2, sprite3

    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
    windw.blit(backgrnd, (0,0))

    textsurface = Font.render('Controls', False, White)
    windw.blit(textsurface, (660, 50))

    ctrls = pygame.image.load("keyboard.png").convert()
    windw.blit(ctrls, (450,150))

    pygame.draw.arc(windw, BLACK, (890,310,70,120), 180*3.14/180, 270*3.14/180, 3)
    pygame.draw.arc(windw, BLACK, (950,325,180,90), 180*3.14/180, 270*3.14/180, 3)
    pygame.draw.arc(windw, BLACK, (580,308,90,120), 270*3.14/180, 360*3.14/180, 3)
    textsurface = Font.render('Scoring', False, White)
    windw.blit(textsurface, (660, 465))

    for i in range(1,4):
        img = pygame.image.load('sprite'+str(i)+'.jpeg')
        img = pygame.transform.scale(img, (70,70))
        windw.blit(img, (600, 480+i*80))

    textsurface = font.render(str(sprite1)+'   points', False, LIGHT)
    windw.blit(textsurface, (720, 475+1*90))

    textsurface = font.render(str(sprite2)+'   points', False, LIGHT)
    windw.blit(textsurface, (720, 465+2*90))

    textsurface = font.render(str(sprite3)+'   points', False, LIGHT)
    windw.blit(textsurface, (720, 465+3*90))

    bot4=pygame.image.load("bot2.jpg")
    bot4 = pygame.transform.scale(bot4, (100, 55))
    windw.blit(bot4, (1300, 732))

    if mouse[0] < 1400 and mouse[0] > 1300 and mouse[1] < 787 and mouse[1] > 732:
        if click[0]:
            image1 = pygame.transform.scale(bot4, (100, 54))
            windw.blit(image1,(1300, 732))
            page = 'mainscreen'
        else:
            image1 = pygame.transform.scale(bot4, (120, 60))
            windw.blit(image1,(1300, 732))

    textsurface = myfont_text.render('Back', False, White)
    windw.blit(textsurface, (1310, 735))

    textsurface = myfont_text.render('SHOOT', False, LIGHT)
    windw.blit(textsurface, (490,400))

    textsurface = myfont_text.render('MOVE LEFT', False, LIGHT)
    windw.blit(textsurface, (830,425))

    textsurface = myfont_text.render('MOVE RIGHT', False, LIGHT)
    windw.blit(textsurface, (1040,385))

def newgame():
    global page, level

    windw.blit(backgrnd, (0,0))

    rec = pygame.image.load("rect0.jpg")
    rec = pygame.transform.scale(rec, (650,755))
    windw.blit(rec, (650,70))

    bot3=pygame.image.load("bot2.jpg")
    bot3 = pygame.transform.scale(bot3, (350, 75))
    windw.blit(bot3, (740, 300))

    textsurface = Font.render('Difficulty Levels', False, White)
    windw.blit(textsurface, (775,150))

    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()

    if mouse[0] < 1100 and mouse[0] > 750 and mouse[1] < 375 and mouse[1] > 300:
        if click[0]:
            image1 = pygame.transform.scale(bot3, (355, 76))
            windw.blit(image1,(740,300))
            level = 1
            page = 'startgame'
        else:
            image1 = pygame.transform.scale(bot3, (365, 80))
            windw.blit(image1,(740,300))

    textsurface = myfont.render('Let me try', False, White)
    windw.blit(textsurface, (790, 300))

    bot3 = pygame.transform.scale(bot3, (350, 75))
    windw.blit(bot3, (800, 425))

    if mouse[0] < 1160 and mouse[0] > 810 and mouse[1] < 490 and mouse[1] > 425:
        if click[0]:
            image1 = pygame.transform.scale(bot3, (355, 76))
            windw.blit(image1,(800,425))
            level = 2
            page = 'startgame'
        else:
            image1 = pygame.transform.scale(bot3, (365, 80))
            windw.blit(image1,(800,425))

    textsurface = myfont.render('Bring them on', False, White)
    windw.blit(textsurface, (815, 427))

    bot3 = pygame.transform.scale(bot3, (350, 75))
    windw.blit(bot3, (870, 550))

    if mouse[0] < 1220 and mouse[0] > 870 and mouse[1] < 625 and mouse[1] > 550:
        if click[0]:
            image1 = pygame.transform.scale(bot3, (355, 76))
            windw.blit(image1,(870,550))
            level = 3
            page = 'startgame'
        else:
            image1 = pygame.transform.scale(bot3, (365, 80))
            windw.blit(image1,(870,550))

    textsurface = myfont.render('Begin the war', False, White)
    windw.blit(textsurface, (885, 553))

    bot3 = pygame.transform.scale(bot3, (150, 65))
    windw.blit(bot3, (950, 670))

    if mouse[0] < 1100 and mouse[0] > 950 and mouse[1] < 735 and mouse[1] > 670:
        if click[0]:
            image1 = pygame.transform.scale(bot3, (155, 66))
            windw.blit(image1,(950,670))
            page = 'mainscreen'
        else:
            image1 = pygame.transform.scale(bot3, (160, 70))
            windw.blit(image1,(950,670))

    textsurface = myfont.render('Back', False, White)
    windw.blit(textsurface, (970, 668))

def mainscreen():
    global done, page

    windw.blit(backgrnd, [0,0])
    title = pygame.image.load("grnd.jpg")
    title = pygame.transform.scale(title, (800,150))

    windw.blit(title, (360, 30))

    bot1=pygame.image.load("bot1.jpg")
    bot1 = pygame.transform.scale(bot1, (230, 65))

    windw.blit(bot1, (1060, 410))
    windw.blit(bot1, (1060, 485))
    windw.blit(bot1, (1060, 560))
    windw.blit(bot1, (1060, 635))
    windw.blit(bot1, (1060, 711))

    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
    if mouse[0] < 1290 and mouse[0]> 1060 and mouse[1] < 475 and mouse[1] > 410:
        if click[0] == 1:
            image = pygame.transform.scale(bot1, (230, 63))
            windw.blit(image,(1060,410))
            page = 'newgame'
        else:
            image = pygame.transform.scale(bot1, (240, 70))
            windw.blit(image,(1060,410))


    text = font.render('New Game', False, White)
    windw.blit(text,(1086,415))

    if mouse[0] < 1290 and mouse[0] > 1060 and mouse[1] < 550 and mouse[1] > 485:
        if click[0] == 1:
            image1 = pygame.transform.scale(bot1, (230, 63))
            windw.blit(image1,(1060,485))
            page = 'resume'
        else:
            image1 = pygame.transform.scale(bot1, (240, 70))
            windw.blit(image1,(1060,485))

    text = font.render('Resume', False, White)
    windw.blit(text,(1108,490))

    if mouse[0] < 1290 and mouse[0] > 1060 and mouse[1] < 625 and mouse[1] > 560:
        if click[0] == 1:
            image2 = pygame.transform.scale(bot1, (230, 63))
            windw.blit(image2,(1060,560))
            page = 'highscore'
        else:
            image2 = pygame.transform.scale(bot1, (240, 70))
            windw.blit(image2,(1060,560))

    text = font.render('High Score', False, White)
    windw.blit(text,(1078,565))

    if mouse[0] < 1290 and mouse[0] > 1060 and mouse[1] < 700 and mouse[1] > 635:
        if click[0] == 1:
            image2 = pygame.transform.scale(bot1, (230, 63))
            windw.blit(image2,(1060,635))
            page = 'howtoplay'
        else:
            image2 = pygame.transform.scale(bot1, (240, 70))
            windw.blit(image2,(1060,635))

    text = font.render('How to Play', False, White)
    windw.blit(text,(1075,638))

    if mouse[0] < 1290 and mouse[0] > 1060 and mouse[1] < 776 and mouse[1] > 711:
        if click[0] == 1:
            image2 = pygame.transform.scale(bot1, (230, 63))
            windw.blit(image2,(1060,711))
            page = 'exitpage'
        else:
            image2 = pygame.transform.scale(bot1, (240, 70))
            windw.blit(image2,(1060,711))

    text = font.render('Exit', False, White)
    windw.blit(text,(1138,718))


#-----------------------------------------------------------------------------------
high()
sound(0)

ss = spaceShip(spaceS, windw, 710, 800, 80, 80)
Enemy = []

for i in range(3):
    for j in range(10):
        key = random.randint(1,3)
        Enemy.append(enemys(enemy[str(key*5)], windw, 260+100*j, 100+100*i, 80, 80))
        Enemy[-1].point = key*5

bullets = []
bullete = []

def initial(level):
    global ss, Enemy, bullets, bullete, lives, score
    ss = spaceShip(spaceS, windw, 710, 800, 80, 80)

    Enemy = []
    addcol = 0
    if level == 3:
        addcol = 1
    for i in range(3+addcol):
        for j in range(10+addcol*2):
            key = random.randint(1,3)
            Enemy.append(enemys(enemy[str(key*5)], windw, 260+100*j-100*(addcol), 100+100*i, 80, 80))
            Enemy[-1].point = key*5

    bullets = []
    bullete = []
    lives = 5
    score = 0

def GameOver():
    global page

    windw.blit(backgrnd, [0,0])
    title = pygame.image.load("grnd.jpg")
    title = pygame.transform.scale(title, (800,150))

    windw.blit(title, (360, 30))

    pygame.draw.rect(windw, White, (400, 300, 700, 300))

    textsurface = myfont.render('Do u want to play again?', False, BLACK)
    windw.blit(textsurface, (550, 340))

    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
    bot4=pygame.image.load("bot2.jpg")
    bot4 = pygame.transform.scale(bot4, (100, 55))
    windw.blit(bot4, (550, 500))

    if mouse[0] < 650 and mouse[0] > 550 and mouse[1] < 555 and mouse[1] > 500:
        if click[0]:
            image1 = pygame.transform.scale(bot4, (100, 54))
            windw.blit(image1,(550, 500))
            page = 'startgame'
        else:
            image1 = pygame.transform.scale(bot4, (120, 60))
            windw.blit(image1,(550, 500))

    textsurface = myfont_text.render('Yes', False, White)
    windw.blit(textsurface, (560, 503))

    windw.blit(bot4, (870, 500))

    if mouse[0] < 970 and mouse[0] > 870 and mouse[1] < 555 and mouse[1] > 500:
        if click[0]:
            image1 = pygame.transform.scale(bot4, (100, 54))
            windw.blit(image1,(870, 500))
            page = 'mainscreen'
            sound(0)
        else:
            image1 = pygame.transform.scale(bot4, (120, 60))
            windw.blit(image1,(870, 500))

    textsurface = myfont_text.render('No', False, White)
    windw.blit(textsurface, (880, 503))

def start():
    global done, page
    while done == False:

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                done = True

        if page == 'mainscreen':
            mainscreen()
        elif page == 'newgame':
            newgame()
        elif page == 'howtoplay':
            howtoplay()
        elif page == 'exitpage':
            exitpage()
        elif page == 'highscore':
            high()
        elif page == 'startgame':
            initial(level)
            page = 'resume'
            startgame(level, windw)
        elif page == 'resume':
            startgame(level, windw)
        elif page == 'gameover':
            GameOver()

        pygame.display.update()

        clock.tick(20) 

start()

pygame.quit()
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-1fe89e79c0d9> in <module>
#     697         clock.tick(20)
#     698
# --> 699 start()
#     700
#     701 pygame.quit()
#
# <ipython-input-1-1fe89e79c0d9> in start()
#     689             startgame(level, windw)
#     690         elif page == 'resume':
# --> 691             startgame(level, windw)
#     692         elif page == 'gameover':
#     693             GameOver()
#
# <ipython-input-1-1fe89e79c0d9> in startgame(level, windw)
#     285             left = False
#     286             ss.rect = pygame.Rect(ss.x, ss.y, ss.width, ss.height)
# --> 287     redrawWindow(windw, background, ss, Enemy, bullets, bullete)
#     288
#     289 def high():
#
# <ipython-input-1-1fe89e79c0d9> in redrawWindow(windw, background, SpaceShip, Enemy, bullets, bullete)
#     154             bullete.pop(bullete.index(bullet))
#     155             lives -= 1
# --> 156             sound(3)
#     157             if lives == 0:
#     158                 page = 'gameover'
#
# <ipython-input-1-1fe89e79c0d9> in sound(flag)
#      71         pygame.mixer.music.play(-1,0.0)
#      72     elif flag == 3:
# ---> 73         pygame.mixer.music.load('explosionship.mp3')
#      74         pygame.mixer.music.play(-1,0.0)
#      75
#
# error: Couldn't open 'explosionship.mp3'
